# %%
Swarovski Scrapper

# %%
import requests
from lxml import html  
import csv,os,json
import requests
import re
from time import sleep
import pandas as pd
import random

# count = int(input())
# n_asin = set()

try:    
    new_data = pd.DataFrame()
    url = 'https://www.swarovski.com/en-US/search/?text=jewelry'
    user_agent_list = ['Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) \
                            Gecko/20100101 Firefox/61.0',
                           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
                            (KHTML, like Gecko) Chrome/66.0.3359.117 Safari/537.36',
                           'Mozilla/5.0 (X11; Linux x86_64; rv:61.0) \
                            Gecko/20100101 Firefox/61.0',
                           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                            AppleWebKit/537.36 (KHTML, like Gecko) \
                            Chrome/60.0.3112.113 Safari/537.36',
                           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                            AppleWebKit/537.36 (KHTML, like Gecko) \
                            Chrome/63.0.3239.132 Safari/537.36',
                           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                            AppleWebKit/537.36 (KHTML, like Gecko) \
                            Chrome/66.0.3359.117 Safari/537.36',
                           'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) \
                            AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.1.2 \
                            Safari/603.3.8',
                           'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) \
                            AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 \
                            Safari/537.36',
                           'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) \
                            AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 \
                            Safari/537.36']
    # a = random.choice(user_agent_list)
    page = requests.get(url, headers={'User-Agent':random.choice(user_agent_list)}).content
    page = page.decode('utf-8')

    pattern = re.compile(r"/p-M(?P<asin>\w+).*")
    asin =  re.findall(pattern,page)

    for i in set(asin):
            page = requests.get('https://www.swarovski.com/en-US/p-M'+str(i), headers={'User-Agent':random.choice(user_agent_list)})
            doc = html.fromstring(page.content)
            XPATH_NAME = '/html/body/div[1]/div/div[3]/div/main/div[2]/div[3]/div/div[2]/div[3]/h1//text()'
            XPATH_SELLER = '/html/body/div[4]/div[2]/div[3]/div[1]/div[1]/div[1]/div[2]/h3/a//text()'
            XPATH_ORIGINAL_PRICE = '/html/body/div[1]/div/div[3]/div/main/div[2]/div[3]/div/div[2]/div[4]/div[2]//text()'
            RAW_NAME = doc.xpath(XPATH_NAME)
            RAW_SELLER = doc.xpath(XPATH_SELLER)
            RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
            XPATH_IMAGE = '/html/body/div[1]/div/div[3]/div/main/div[2]/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div[1]/div/img/@data-image-zoom'
            RAW_IMAGE = doc.xpath(XPATH_IMAGE)
            RAW_IMAGE

                    #print(RAW_NAME,RAW_SELLER,RAW_ORIGINAL_PRICE)
            NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
            SELLER = '  '.join([i.strip() for i in RAW_SELLER]) if RAW_SELLER else None
            ORIGINAL_PRICE = ' '.join(RAW_ORIGINAL_PRICE).strip() if RAW_ORIGINAL_PRICE else None
            RAW_IMAGE = ''.join(RAW_IMAGE) if len(RAW_IMAGE)>0 else None
                    #print(NAME,SELLER,ORIGINAL_PRI        data = pd.DataFrame([[NAME,SELLER,ORIGINAL_PRICE,RAW_IMAGE]],columns = ['NAME','SELLER','ORIGINAL_PRICE','IMAGE_URL'])
            new_data = new_data.append(data,sort=False)
            new_data = new_data.drop_duplicates()
                        #new_data = pd.concat(data)
            print(new_data)
        
except Exception as e:
    print(e)
new_data.to_csv('/home/ai101/Documents/Rushiket/swarovski.csv',index=False)
# Out:
#   File "<ipython-input-45-38df3b9c4597>", line 74
#     # new_data.to_csv('/home/ai101/Documents/Rushiket/swarovski.csv',index=False)
#                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
Amazon Scraper

# %%
import requests
from lxml import html  
import csv,os,json
import requests
import re
from time import sleep
import pandas as pd
import random
try:
    new_data = pd.DataFrame()
    url = 'https://www.amazon.com/s?keywords=jewelry'
    user_agent_list = ['Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) \
                        Gecko/20100101 Firefox/61.0',
                       'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
                        (KHTML, like Gecko) Chrome/66.0.3359.117 Safari/537.36',
                       'Mozilla/5.0 (X11; Linux x86_64; rv:61.0) \
                        Gecko/20100101 Firefox/61.0',
                       'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                        AppleWebKit/537.36 (KHTML, like Gecko) \
                        Chrome/60.0.3112.113 Safari/537.36',
                       'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                        AppleWebKit/537.36 (KHTML, like Gecko) \
                        Chrome/63.0.3239.132 Safari/537.36',
                       'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                        AppleWebKit/537.36 (KHTML, like Gecko) \
                        Chrome/66.0.3359.117 Safari/537.36',
                       'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) \
                        AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.1.2 \
                        Safari/603.3.8',
                       'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) \
                        AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 \
                        Safari/537.36',
                       'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) \
                        AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 \
                        Safari/537.36']
    # a = random.choice(user_agent_list)
    page = requests.get(url, headers={'User-Agent':random.choice(user_agent_list)}).content
    page = page.decode('utf-8')
    
    pattern = re.compile(r"/dp/(?P<asin>\w+).*")
    asin =  re.findall(pattern,page)

    for i in set(asin):
        page = requests.get('http://www.amazon.com/dp/'+str(i), headers={'User-Agent':random.choice(user_agent_list)})
        doc = html.fromstring(page.content)
        XPATH_NAME = '//*[@id="productTitle"]//text()'
        XPATH_SELLER = '//*[@id="sellerProfileTriggerId"]//text()'
        XPATH_ORIGINAL_PRICE = '//*[@id="priceblock_ourprice"]//text()'
        RAW_NAME = doc.xpath(XPATH_NAME)
        RAW_SELLER = doc.xpath(XPATH_SELLER)
        RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
        XPATH_IMAGE = '//div[@id="imgTagWrapperId"]/img/@data-old-hires'
        RAW_IMAGE = doc.xpath(XPATH_IMAGE)
        RAW_IMAGE

#             print(RAW_NAME,RAW_SELLER,RAW_ORIGINAL_PRICE)
        NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
        SELLER = '  '.join([i.strip() for i in RAW_SELLER]) if RAW_SELLER else None
        ORIGINAL_PRICE = ' '.join(RAW_ORIGINAL_PRICE).strip() if RAW_ORIGINAL_PRICE else None
        RAW_IMAGE = ''.join(RAW_IMAGE) if len(RAW_IMAGE)>0 else None
#             print(NAME,SELLER,ORIGINAL_PRICE)
        data = pd.DataFrame([[NAME,SELLER,ORIGINAL_PRICE,RAW_IMAGE]],columns = ['NAME','SELLER','ORIGINAL_PRICE','IMAGE_URL'])
        new_data = new_data.append(data,sort=False)
        new_data = new_data.drop_duplicates()
    #     new_data = pd.concat(data)
        print(new_data)
    c+=1
    print(c)
    
#         print(new_data.head())
except Exception as e:
    print(e)
new_data.to_csv('/home/ai101/Documents/Rushiket/amazon.csv',index=False)
# Out:
#    NAME SELLER ORIGINAL_PRICE IMAGE_URL
# 0  None   None           None      None
#                                                 NAME    SELLER ORIGINAL_PRICE  \
# 0                                               None      None           None
# 0  AZORA Womens Leather Cuff Bracelet Baroque Pea...  AZORA US         $14.59
#
#                                            IMAGE_URL
# 0                                               None
# 0  https://images-na.ssl-images-amazon.com/images...
#                                                 NAME    SELLER  \
# 0                                               None      None
# 0  AZORA Womens Leather Cuff Bracelet Baroque Pea...  AZORA US
# 0  Plated Sterling Silver Round-Cut All-Around Ba...      None
#
#    ORIGINAL_PRICE                                          IMAGE_URL
# 0            None                                               None
# 0          $14.59  https://images-na.ssl-images-amazon.com/images...
# 0  $8.56 - $30.00  https://images-na.ssl-images-amazon.com/images...
#                                                 NAME              SELLER  \
# 0                                               None                None
# 0  AZORA Womens Leather Cuff Bracelet Baroque Pea...            AZORA US
# 0  Plated Sterling Silver Round-Cut All-Around Ba...                None
# 0  Comfify Rustic Jewelry Organizer – Wall Mounte...  HOME & KITCHEN USA
#
#    ORIGINAL_PRICE                                          IMAGE_URL
# 0            None                                               None
# 0          $14.59  https://images-na.ssl-images-amazon.com/images...
# 0  $8.56 - $30.00  https://images-na.ssl-images-amazon.com/images...
# 0          $24.99  https://images-na.ssl-images-amazon.com/images...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/urllib3-1.25.3-py3.5.egg/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378                 # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-e87467486a5d> in <module>
#      42
#      43     for i in set(asin):
# ---> 44         page = requests.get('http://www.amazon.com/dp/'+str(i), headers={'User-Agent':random.choice(user_agent_list)})
#      45         doc = html.fromstring(page.content)
#      46         XPATH_NAME = '//*[@id="productTitle"]//text()'
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.5/dist-packages/requests-2.22.0-py3.5.egg/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.5/dist-packages/urllib3-1.25.3-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     601                                                   timeout=timeout_obj,
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#     605             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.5/dist-packages/urllib3-1.25.3-py3.5.egg/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 # Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /usr/local/lib/python3.5/dist-packages/urllib3-1.25.3-py3.5.egg/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     302     def recv_into(self, *args, **kwargs):
#     303         try:
# --> 304             return self.connection.recv_into(*args, **kwargs)
#     305         except OpenSSL.SSL.SysCallError as e:
#     306             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /usr/local/lib/python3.5/dist-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [raw]
# Etsy Scraper

# %%
import requests
from lxml import html  
import csv,os,json
import requests
import re
from time import sleep
import pandas as pd
import random

count = int(input())
# n_asin = set()

try:    
    new_data = pd.DataFrame()
    for i in range (1,count):
        url = 'https://www.etsy.com/in-en/search?q=jewellery&ref=pagination&page='+str(count)
        user_agent_list = ['Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) \
                            Gecko/20100101 Firefox/61.0',
                           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
                            (KHTML, like Gecko) Chrome/66.0.3359.117 Safari/537.36',
                           'Mozilla/5.0 (X11; Linux x86_64; rv:61.0) \
                            Gecko/20100101 Firefox/61.0',
                           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                            AppleWebKit/537.36 (KHTML, like Gecko) \
                            Chrome/60.0.3112.113 Safari/537.36',
                           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                            AppleWebKit/537.36 (KHTML, like Gecko) \
                            Chrome/63.0.3239.132 Safari/537.36',
                           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                            AppleWebKit/537.36 (KHTML, like Gecko) \
                            Chrome/66.0.3359.117 Safari/537.36',
                           'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) \
                            AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.1.2 \
                            Safari/603.3.8',
                           'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) \
                            AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 \
                            Safari/537.36',
                           'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) \
                            AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 \
                            Safari/537.36']
        # a = random.choice(user_agent_list)
        page = requests.get(url, headers={'User-Agent':random.choice(user_agent_list)}).content
        page = page.decode('utf-8')

        pattern = re.compile(r"/listing/(?P<asin>\w+).*")
        asin =  re.findall(pattern,page)

        for i in set(asin):
                page = requests.get('https://www.etsy.com/in-en/listing/'+str(i), headers={'User-Agent':random.choice(user_agent_list)})
                doc = html.fromstring(page.content)
                XPATH_NAME = '/html/body/div[5]/div[1]/div[1]/div/div[2]/div/div[1]/div[2]/h1//text()'
                XPATH_SELLER = '/html/body/div[5]/div[1]/div[1]/div/div[2]/div/div[1]/div[1]/a[1]//text()'
                XPATH_ORIGINAL_PRICE = '/html/body/div[5]/div[1]/div[1]/div/div[2]/div/div[1]/div[3]/p[1]/span[1]//text()'
                RAW_NAME = doc.xpath(XPATH_NAME)
                RAW_SELLER = doc.xpath(XPATH_SELLER)
                RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
                XPATH_IMAGE = '/html/body/div[5]/div[1]/div[1]/div/div[1]/div[1]/div[2]/div[1]/ul/li[1]/img/@data-src-zoom-image'
                RAW_IMAGE = doc.xpath(XPATH_IMAGE)
                RAW_IMAGE

        #         print(RAW_NAME,RAW_SELLER,RAW_ORIGINAL_PRICE)
                NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
                SELLER = '  '.join([i.strip() for i in RAW_SELLER]) if RAW_SELLER else None
                ORIGINAL_PRICE = ' '.join(RAW_ORIGINAL_PRICE).strip() if RAW_ORIGINAL_PRICE else None
                RAW_IMAGE = ''.join(RAW_IMAGE) if len(RAW_IMAGE)>0 else None
        #             print(NAME,SELLER,ORIGINAL_PRICE)
                data = pd.DataFrame([[NAME,SELLER,ORIGINAL_PRICE,RAW_IMAGE]],columns = ['NAME','SELLER','ORIGINAL_PRICE','IMAGE_URL'])
                new_data = new_data.append(data,sort=False)
                new_data = new_data.drop_duplicates()
            #     new_data = pd.concat(data)
                print(new_data)
        
except Exception as e:
    print(e)
new_data.to_csv('/home/ai101/Documents/Rushiket/etsy.csv',index=False)
# Out:
# 2
#                                                 NAME          SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...  TheCharmingEye
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
#                                                 NAME           SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...   TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...  SilverCreation8
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...         ZaraRaquelle
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
# 0       US$ 7.10  https://i.etsystatic.com/20714909/r/il/4f5539/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...         ZaraRaquelle
# 0  Puprle Amethyst Pendant - amethyst Pendant - F...     NaturalGemJewels
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
# 0       US$ 7.10  https://i.etsystatic.com/20714909/r/il/4f5539/...
# 0      US$ 35.00  https://i.etsystatic.com/17783343/r/il/44c0f5/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...         ZaraRaquelle
# 0  Puprle Amethyst Pendant - amethyst Pendant - F...     NaturalGemJewels
# 0  Hobbycrete concrete mix 9 oz. kit for making c...           Hobbycrete
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
# 0       US$ 7.10  https://i.etsystatic.com/20714909/r/il/4f5539/...
# 0      US$ 35.00  https://i.etsystatic.com/17783343/r/il/44c0f5/...
# 0      US$ 19.95  https://i.etsystatic.com/8961125/r/il/5c4aa2/5...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...         ZaraRaquelle
# 0  Puprle Amethyst Pendant - amethyst Pendant - F...     NaturalGemJewels
# 0  Hobbycrete concrete mix 9 oz. kit for making c...           Hobbycrete
# 0  Pear Shaped Dark Brown, Multi Stripped Wooden ...  DevotionArtBoutique
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
# 0       US$ 7.10  https://i.etsystatic.com/20714909/r/il/4f5539/...
# 0      US$ 35.00  https://i.etsystatic.com/17783343/r/il/44c0f5/...
# 0      US$ 19.95  https://i.etsystatic.com/8961125/r/il/5c4aa2/5...
# 0      US$ 17.10  https://i.etsystatic.com/20538160/r/il/24786a/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...         ZaraRaquelle
# 0  Puprle Amethyst Pendant - amethyst Pendant - F...     NaturalGemJewels
# 0  Hobbycrete concrete mix 9 oz. kit for making c...           Hobbycrete
# 0  Pear Shaped Dark Brown, Multi Stripped Wooden ...  DevotionArtBoutique
# 0  Pearl Bridesmaid Jewelry Set of 5, Bridesmaid ...        SarinaJewelry
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
# 0       US$ 7.10  https://i.etsystatic.com/20714909/r/il/4f5539/...
# 0      US$ 35.00  https://i.etsystatic.com/17783343/r/il/44c0f5/...
# 0      US$ 19.95  https://i.etsystatic.com/8961125/r/il/5c4aa2/5...
# 0      US$ 17.10  https://i.etsystatic.com/20538160/r/il/24786a/...
# 0           None  https://i.etsystatic.com/13851771/r/il/e664f9/...
#                                                 NAME               SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...       TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...      SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...  ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...              JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...         ZaraRaquelle
# 0  Puprle Amethyst Pendant - amethyst Pendant - F...     NaturalGemJewels
# 0  Hobbycrete concrete mix 9 oz. kit for making c...           Hobbycrete
# 0  Pear Shaped Dark Brown, Multi Stripped Wooden ...  DevotionArtBoutique
# 0  Pearl Bridesmaid Jewelry Set of 5, Bridesmaid ...        SarinaJewelry
# 0  Real Natural Baltic Amber stone round bead ela...          TopAmberCom
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 0      US$ 15.00  https://i.etsystatic.com/7724392/r/il/ba4c8a/1...
# 0      US$ 22.63  https://i.etsystatic.com/18884499/r/il/ff7e71/...
# 0     US$ 35.00+  https://i.etsystatic.com/14610676/r/il/4c1fe6/...
# 0           None  https://i.etsystatic.com/17511105/r/il/ca29c4/...
# 0       US$ 7.10  https://i.etsystatic.com/20714909/r/il/4f5539/...
# 0      US$ 35.00  https://i.etsystatic.com/17783343/r/il/44c0f5/...
# 0      US$ 19.95  https://i.etsystatic.com/8961125/r/il/5c4aa2/5...
# 0      US$ 17.10  https://i.etsystatic.com/20538160/r/il/24786a/...
# 0           None  https://i.etsystatic.com/13851771/r/il/e664f9/...
# 0      US$ 22.94  https://i.etsystatic.com/20220486/r/il/a703cb/...
#                                                 NAME                SELLER  \
# 0  Pegasus Necklace, gold metal pegasus, black le...        TheCharmingEye
# 0  Genuine k-2 Blue Jasper Handmade 925 Sterling ...       SilverCreation8
# 0  Personalized Bridesmaids Gift,Travel Jewelry C...   ABRIDEANDAGROOMSHOP
# 0  Two Name Necklace, Dainty Name Necklace for He...               JWLGANG
# 0  Alphabet Beads 250pc Round White/Black Letters...          ZaraRaquelle
# 0  Puprle Amethyst Pendant - amethyst Pendant - F...      NaturalGemJewels
# 0  Hobbycrete concrete mix 9 oz. kit for making c...            Hobbycrete
# 0  Pear Shaped Dark Brown, Multi Stripped Wooden ...   DevotionArtBoutique
# 0  Pearl Bridesmaid Jewelry Set of 5, Bridesmaid ...         SarinaJewelry
# 0  Real Natural Baltic Amber stone round bead ela...           TopAmberCom
# 0  Hangry, Funny Gift, Funny Jewelry, Gag Gift, H...  StitchedandStampedCo
#
#   ORIGINAL_PRICE                                          IMAGE_URL
# 